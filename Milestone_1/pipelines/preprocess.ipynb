# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/raw/cardano_5y.csv', parse_dates=['open_time'])

# %%
df.head()
# Out:
#             open_time     open     high      low    close      volume
# 0 2020-11-18 06:00:00  0.10447  0.10640  0.10408  0.10587  30552966.4
# 1 2020-11-18 07:00:00  0.10587  0.10696  0.10467  0.10687  27057619.6
# 2 2020-11-18 08:00:00  0.10692  0.10704  0.10632  0.10656  17147608.0
# 3 2020-11-18 09:00:00  0.10658  0.10666  0.10550  0.10636  22508213.3
# 4 2020-11-18 10:00:00  0.10639  0.10750  0.10594  0.10747  12270594.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43830 entries, 0 to 43829
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   open_time  43830 non-null  datetime64[ns]
#  1   open       43810 non-null  float64
#  2   high       43810 non-null  float64
#  3   low        43810 non-null  float64
#  4   close      43810 non-null  float64
#  5   volume     43810 non-null  float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 2.0 MB

# %%
df.describe()
# Out:
#                  open_time          open          high           low  \
# count                43830  43810.000000  43810.000000  43810.000000
# mean   2023-05-20 08:30:00      0.739610      0.745498      0.733378
# min    2020-11-18 06:00:00      0.104470      0.104940      0.103370
# 25%    2022-02-17 19:15:00      0.368900      0.371000      0.366600
# 50%    2023-05-20 08:30:00      0.562100      0.566400      0.557650
# 75%    2024-08-18 21:45:00      0.934697      0.943000      0.926000
# max    2025-11-18 11:00:00      3.095000      3.101000      3.048000
# std                    NaN      0.522906      0.527874      0.517603
#
#               close        volume
# count  43810.000000  4.381000e+04
# mean       0.739617  9.636120e+06
# min        0.104490  0.000000e+00
# 25%        0.368900  2.842061e+06
# 50%        0.562200  5.131130e+06
# 75%        0.934650  1.035647e+07
# max        3.095000  4.475996e+08
# std        0.522904  1.467976e+07

# %%
df.isnull().sum()
# Out:
# open_time     0
# open         20
# high         20
# low          20
# close        20
# volume       20
# dtype: int64

# %%
zero_counts = (df == 0).sum()
print("Number of zeros per column:\n", zero_counts)
# Out:
# Number of zeros per column:
#  open_time    0
# open         0
# high         0
# low          0
# close        0
# volume       2
# dtype: int64

# %%
df = df.set_index("open_time").sort_index()

# %%
df.head()
# Out:
#                         open     high      low    close      volume
# open_time
# 2020-11-18 06:00:00  0.10447  0.10640  0.10408  0.10587  30552966.4
# 2020-11-18 07:00:00  0.10587  0.10696  0.10467  0.10687  27057619.6
# 2020-11-18 08:00:00  0.10692  0.10704  0.10632  0.10656  17147608.0
# 2020-11-18 09:00:00  0.10658  0.10666  0.10550  0.10636  22508213.3
# 2020-11-18 10:00:00  0.10639  0.10750  0.10594  0.10747  12270594.2

# %%
df["missing_flag"] = df["open"].isna().astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 43830 entries, 2020-11-18 06:00:00 to 2025-11-18 11:00:00
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   open          43810 non-null  float64
#  1   high          43810 non-null  float64
#  2   low           43810 non-null  float64
#  3   close         43810 non-null  float64
#  4   volume        43810 non-null  float64
#  5   missing_flag  43830 non-null  int64
# dtypes: float64(5), int64(1)
# memory usage: 2.3 MB

# %%
df.head()
# Out:
#                         open     high      low    close      volume  \
# open_time
# 2020-11-18 06:00:00  0.10447  0.10640  0.10408  0.10587  30552966.4
# 2020-11-18 07:00:00  0.10587  0.10696  0.10467  0.10687  27057619.6
# 2020-11-18 08:00:00  0.10692  0.10704  0.10632  0.10656  17147608.0
# 2020-11-18 09:00:00  0.10658  0.10666  0.10550  0.10636  22508213.3
# 2020-11-18 10:00:00  0.10639  0.10750  0.10594  0.10747  12270594.2
#
#                      missing_flag
# open_time
# 2020-11-18 06:00:00             0
# 2020-11-18 07:00:00             0
# 2020-11-18 08:00:00             0
# 2020-11-18 09:00:00             0
# 2020-11-18 10:00:00             0

# %%
df.isnull().sum()
# Out:
# open            20
# high            20
# low             20
# close           20
# volume          20
# missing_flag     0
# dtype: int64

# %%
df["missing_flag"] = df["open"].isna().astype(int)

# %%
df[["open","high","low","close","volume"]] = (
    df[["open","high","low","close","volume"]].ffill()
)

# %%
df.isnull().sum()
# Out:
# open            0
# high            0
# low             0
# close           0
# volume          0
# missing_flag    0
# dtype: int64

# %% [markdown]
# # Feature Engineering

# %%
df["return_1h"] = df["close"].pct_change().fillna(0)
df["volatility_24h"] = df["return_1h"].rolling(24).std().fillna(0)

# %%
df.describe()
# Out:
#                open          high           low         close        volume  \
# count  43830.000000  43830.000000  43830.000000  43830.000000  4.383000e+04
# mean       0.739742      0.745633      0.733510      0.739751  9.638699e+06
# std        0.523045      0.528019      0.517744      0.523048  1.467865e+07
# min        0.104470      0.104940      0.103370      0.104490  0.000000e+00
# 25%        0.368900      0.371000      0.366600      0.368900  2.842061e+06
# 50%        0.562200      0.566500      0.557750      0.562250  5.132363e+06
# 75%        0.935000      0.943615      0.926475      0.935000  1.036538e+07
# max        3.095000      3.101000      3.048000      3.095000  4.475996e+08
#
#        missing_flag     return_1h  volatility_24h
# count  43830.000000  43830.000000    43830.000000
# mean       0.000456      0.000097        0.009425
# std        0.021357      0.011234        0.006150
# min        0.000000     -0.215392        0.000000
# 25%        0.000000     -0.004541        0.005724
# 50%        0.000000      0.000000        0.007849
# 75%        0.000000      0.004632        0.011299
# max        1.000000      0.337091        0.085205

# %%
df["ma_24"] = df["close"].rolling(24).mean()
df["ma_168"] = df["close"].rolling(168).mean()
df["ma_ratio"] = df["ma_24"] / df["ma_168"]

# %%
df["vol_change"] = df["volume"].pct_change().fillna(0)

# %%
df.head()
# Out:
#                         open     high      low    close      volume  \
# open_time
# 2020-11-18 06:00:00  0.10447  0.10640  0.10408  0.10587  30552966.4
# 2020-11-18 07:00:00  0.10587  0.10696  0.10467  0.10687  27057619.6
# 2020-11-18 08:00:00  0.10692  0.10704  0.10632  0.10656  17147608.0
# 2020-11-18 09:00:00  0.10658  0.10666  0.10550  0.10636  22508213.3
# 2020-11-18 10:00:00  0.10639  0.10750  0.10594  0.10747  12270594.2
#
#                      missing_flag  return_1h  volatility_24h  ma_24  ma_168  \
# open_time
# 2020-11-18 06:00:00             0   0.000000             0.0    NaN     NaN
# 2020-11-18 07:00:00             0   0.009446             0.0    NaN     NaN
# 2020-11-18 08:00:00             0  -0.002901             0.0    NaN     NaN
# 2020-11-18 09:00:00             0  -0.001877             0.0    NaN     NaN
# 2020-11-18 10:00:00             0   0.010436             0.0    NaN     NaN
#
#                      ma_ratio  vol_change
# open_time
# 2020-11-18 06:00:00       NaN    0.000000
# 2020-11-18 07:00:00       NaN   -0.114403
# 2020-11-18 08:00:00       NaN   -0.366256
# 2020-11-18 09:00:00       NaN    0.312615
# 2020-11-18 10:00:00       NaN   -0.454839

# %%
df["ma_24"] = df["ma_24"].bfill()
df["ma_168"] = df["ma_168"].bfill()
df["ma_ratio"] = df["ma_ratio"].bfill()

# %%
df.isnull().sum()
# Out:
# open              0
# high              0
# low               0
# close             0
# volume            0
# missing_flag      0
# return_1h         0
# volatility_24h    0
# ma_24             0
# ma_168            0
# ma_ratio          0
# vol_change        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 43830 entries, 2020-11-18 06:00:00 to 2025-11-18 11:00:00
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   open            43830 non-null  float64
#  1   high            43830 non-null  float64
#  2   low             43830 non-null  float64
#  3   close           43830 non-null  float64
#  4   volume          43830 non-null  float64
#  5   missing_flag    43830 non-null  int64
#  6   return_1h       43830 non-null  float64
#  7   volatility_24h  43830 non-null  float64
#  8   ma_24           43830 non-null  float64
#  9   ma_168          43830 non-null  float64
#  10  ma_ratio        43830 non-null  float64
#  11  vol_change      43830 non-null  float64
# dtypes: float64(11), int64(1)
# memory usage: 4.3 MB

# %%
df.isnull().sum()
# Out:
# open              0
# high              0
# low               0
# close             0
# volume            0
# missing_flag      0
# return_1h         0
# volatility_24h    0
# ma_24             0
# ma_168            0
# ma_ratio          0
# vol_change        0
# dtype: int64

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.ffill(inplace=True)

# %%
df.to_csv('../data/processed/cardano_processed.csv', index=True)
