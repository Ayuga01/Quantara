# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# # Data Loading

# %%
X_train = np.load("Split/binanceCoin/X_train.npy")
y_train = np.load("Split/binanceCoin/y_train.npy")

X_val = np.load("Split/binanceCoin/X_val.npy")
y_val = np.load("Split/binanceCoin/y_val.npy")

X_test = np.load("Split/binanceCoin/X_test.npy")
y_test = np.load("Split/binanceCoin/y_test.npy")

print("Loaded shapes:")
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
print("X_val:", X_val.shape)
print("y_val:", y_val.shape)
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)

# %% [markdown]
# # Modle Building

# %%
model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),

    LSTM(32, return_sequences=False),
    Dropout(0.2),

    Dense(16, activation="relu"),
    Dense(1)   # predicting the next-hour closing price (scaled)
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss="mse"
)

model.summary()
