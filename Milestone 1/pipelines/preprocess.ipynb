# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('../data/raw/solana_5y.csv')

# %%
df.head()
# Out:
#              open_time    open    high     low   close     volume
# 0  2020-11-18 06:00:00  2.0818  2.1248  2.0772  2.1085  202719.77
# 1  2020-11-18 07:00:00  2.1065  2.1365  2.0932  2.1289  123056.45
# 2  2020-11-18 08:00:00  2.1263  2.1423  2.1209  2.1243   27228.63
# 3  2020-11-18 09:00:00  2.1265  2.1296  2.0851  2.0957   76816.40
# 4  2020-11-18 10:00:00  2.0957  2.1152  2.0801  2.1152   63006.25

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43830 entries, 0 to 43829
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   open_time  43830 non-null  object
#  1   open       43810 non-null  float64
#  2   high       43810 non-null  float64
#  3   low        43810 non-null  float64
#  4   close      43810 non-null  float64
#  5   volume     43810 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 2.0+ MB

# %%
df.describe()
# Out:
#                open          high           low         close        volume
# count  43810.000000  43810.000000  43810.000000  43810.000000  4.381000e+04
# mean      95.509218     96.244494     94.743311     95.512204  1.909799e+05
# std       72.863244     73.362662     72.337607     72.862214  2.150693e+05
# min        1.184300      1.218200      1.030100      1.183200  0.000000e+00
# 25%       24.540000     24.720000     24.390000     24.540000  7.581904e+04
# 50%       90.690000     91.440000     89.885000     90.700000  1.272345e+05
# 75%      157.010000    158.050000    155.960000    157.000000  2.258899e+05
# max      286.230000    295.830000    284.200000    286.240000  4.974114e+06

# %%
df.isnull().sum()
# Out:
# open_time     0
# open         20
# high         20
# low          20
# close        20
# volume       20
# dtype: int64

# %%
df.index=pd.to_datetime(df.open_time)
df = df.sort_index()

# %%
df.head()
# Out:
#                                open_time    open    high     low   close  \
# open_time
# 2020-11-18 06:00:00  2020-11-18 06:00:00  2.0818  2.1248  2.0772  2.1085
# 2020-11-18 07:00:00  2020-11-18 07:00:00  2.1065  2.1365  2.0932  2.1289
# 2020-11-18 08:00:00  2020-11-18 08:00:00  2.1263  2.1423  2.1209  2.1243
# 2020-11-18 09:00:00  2020-11-18 09:00:00  2.1265  2.1296  2.0851  2.0957
# 2020-11-18 10:00:00  2020-11-18 10:00:00  2.0957  2.1152  2.0801  2.1152
#
#                         volume
# open_time
# 2020-11-18 06:00:00  202719.77
# 2020-11-18 07:00:00  123056.45
# 2020-11-18 08:00:00   27228.63
# 2020-11-18 09:00:00   76816.40
# 2020-11-18 10:00:00   63006.25

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 43830 entries, 2020-11-18 06:00:00 to 2025-11-18 11:00:00
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   open_time  43830 non-null  object
#  1   open       43810 non-null  float64
#  2   high       43810 non-null  float64
#  3   low        43810 non-null  float64
#  4   close      43810 non-null  float64
#  5   volume     43810 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 2.3+ MB

# %%
df.drop(['open_time'],axis=1, inplace=True)

# %%
df.head()
# Out:
#                        open    high     low   close     volume
# open_time
# 2020-11-18 06:00:00  2.0818  2.1248  2.0772  2.1085  202719.77
# 2020-11-18 07:00:00  2.1065  2.1365  2.0932  2.1289  123056.45
# 2020-11-18 08:00:00  2.1263  2.1423  2.1209  2.1243   27228.63
# 2020-11-18 09:00:00  2.1265  2.1296  2.0851  2.0957   76816.40
# 2020-11-18 10:00:00  2.0957  2.1152  2.0801  2.1152   63006.25

# %%
df.isnull().sum()
# Out:
# open      20
# high      20
# low       20
# close     20
# volume    20
# dtype: int64

# %%
df["missing_flag"] = df["open"].isna().astype(int)

# %%
df[["open","high","low","close","volume"]] = (
    df[["open","high","low","close","volume"]].ffill()
)

# %%
df.isnull().sum()
# Out:
# open            0
# high            0
# low             0
# close           0
# volume          0
# missing_flag    0
# dtype: int64

# %% [markdown]
# # Feature Engineering

# %%
df["return_1h"] = df["close"].pct_change().fillna(0)

# %%
df["volatility_24h"] = df["return_1h"].rolling(24).std().fillna(0)

# %%
df.describe()
# Out:
#                open          high           low         close        volume  \
# count  43830.000000  43830.000000  43830.000000  43830.000000  4.383000e+04
# mean      95.481162     96.216293     94.715492     95.484251  1.909379e+05
# std       72.863212     73.362546     72.337478     72.862063  2.150490e+05
# min        1.184300      1.218200      1.030100      1.183200  0.000000e+00
# 25%       24.540000     24.712250     24.390000     24.537000  7.580137e+04
# 50%       90.660000     91.365000     89.815000     90.660000  1.271947e+05
# 75%      156.977500    158.027500    155.947500    156.977500  2.258820e+05
# max      286.230000    295.830000    284.200000    286.240000  4.974114e+06
#
#        missing_flag     return_1h  volatility_24h
# count  43830.000000  43830.000000    43830.000000
# mean       0.000456      0.000179        0.010986
# std        0.021357      0.012941        0.006874
# min        0.000000     -0.192840        0.000000
# 25%        0.000000     -0.005372        0.006701
# 50%        0.000000      0.000000        0.009242
# 75%        0.000000      0.005421        0.013142
# max        1.000000      0.186463        0.072218

# %%
df["ma_24"] = df["close"].rolling(24).mean()
df["ma_168"] = df["close"].rolling(168).mean()
df["ma_ratio"] = df["ma_24"] / df["ma_168"]

# %%
df["vol_change"] = df["volume"].pct_change().fillna(0)

# %%
df.head()
# Out:
#                        open    high     low   close     volume  missing_flag  \
# open_time
# 2020-11-18 06:00:00  2.0818  2.1248  2.0772  2.1085  202719.77             0
# 2020-11-18 07:00:00  2.1065  2.1365  2.0932  2.1289  123056.45             0
# 2020-11-18 08:00:00  2.1263  2.1423  2.1209  2.1243   27228.63             0
# 2020-11-18 09:00:00  2.1265  2.1296  2.0851  2.0957   76816.40             0
# 2020-11-18 10:00:00  2.0957  2.1152  2.0801  2.1152   63006.25             0
#
#                      return_1h  volatility_24h  ma_24  ma_168  ma_ratio  \
# open_time
# 2020-11-18 06:00:00   0.000000             0.0    NaN     NaN       NaN
# 2020-11-18 07:00:00   0.009675             0.0    NaN     NaN       NaN
# 2020-11-18 08:00:00  -0.002161             0.0    NaN     NaN       NaN
# 2020-11-18 09:00:00  -0.013463             0.0    NaN     NaN       NaN
# 2020-11-18 10:00:00   0.009305             0.0    NaN     NaN       NaN
#
#                      vol_change
# open_time
# 2020-11-18 06:00:00    0.000000
# 2020-11-18 07:00:00   -0.392973
# 2020-11-18 08:00:00   -0.778731
# 2020-11-18 09:00:00    1.821163
# 2020-11-18 10:00:00   -0.179781

# %%
df.isnull().sum()
# Out:
# open                0
# high                0
# low                 0
# close               0
# volume              0
# missing_flag        0
# return_1h           0
# volatility_24h      0
# ma_24              23
# ma_168            167
# ma_ratio          167
# vol_change          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 43830 entries, 2020-11-18 06:00:00 to 2025-11-18 11:00:00
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   open            43830 non-null  float64
#  1   high            43830 non-null  float64
#  2   low             43830 non-null  float64
#  3   close           43830 non-null  float64
#  4   volume          43830 non-null  float64
#  5   missing_flag    43830 non-null  int64
#  6   return_1h       43830 non-null  float64
#  7   volatility_24h  43830 non-null  float64
#  8   ma_24           43807 non-null  float64
#  9   ma_168          43663 non-null  float64
#  10  ma_ratio        43663 non-null  float64
#  11  vol_change      43830 non-null  float64
# dtypes: float64(11), int64(1)
# memory usage: 4.3 MB

# %%
df["ma_24"] = df["ma_24"].bfill()
df["ma_168"] = df["ma_168"].bfill()
df["ma_ratio"] = df["ma_ratio"].bfill()

# %%
df.isnull().sum()
# Out:
# open              0
# high              0
# low               0
# close             0
# volume            0
# missing_flag      0
# return_1h         0
# volatility_24h    0
# ma_24             0
# ma_168            0
# ma_ratio          0
# vol_change        0
# dtype: int64

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.ffill(inplace=True)

# %% [markdown]
# # Scaling

# %%
features=['open','high','low','close',
          'volume','missing_flag','return_1h','volatility_24h',
          'ma_24','ma_168','ma_ratio','vol_change']
scaler=MinMaxScaler()
df[features] = scaler.fit_transform(df[features])

# %%
df.head()
# Out:
#                          open      high       low     close    volume  \
# open_time
# 2020-11-18 06:00:00  0.003149  0.003077  0.003698  0.003246  0.040755
# 2020-11-18 07:00:00  0.003235  0.003117  0.003754  0.003318  0.024739
# 2020-11-18 08:00:00  0.003305  0.003137  0.003852  0.003301  0.005474
# 2020-11-18 09:00:00  0.003305  0.003094  0.003726  0.003201  0.015443
# 2020-11-18 10:00:00  0.003197  0.003045  0.003708  0.003270  0.012667
#
#                      missing_flag  return_1h  volatility_24h    ma_24  \
# open_time
# 2020-11-18 06:00:00           0.0   0.508406             0.0  0.00308
# 2020-11-18 07:00:00           0.0   0.533914             0.0  0.00308
# 2020-11-18 08:00:00           0.0   0.502710             0.0  0.00308
# 2020-11-18 09:00:00           0.0   0.472912             0.0  0.00308
# 2020-11-18 10:00:00           0.0   0.532937             0.0  0.00308
#
#                        ma_168  ma_ratio  vol_change
# open_time
# 2020-11-18 06:00:00  0.003226  0.573355    0.014270
# 2020-11-18 07:00:00  0.003226  0.573355    0.008662
# 2020-11-18 08:00:00  0.003226  0.573355    0.003158
# 2020-11-18 09:00:00  0.003226  0.573355    0.040258
# 2020-11-18 10:00:00  0.003226  0.573355    0.011705

# %%
df.to_csv('../data/processed/solana_5y.csv', index=False)
